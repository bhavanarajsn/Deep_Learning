# %%
#Mounting Google Drive in Colab notebook
from google.colab import drive
import numpy as np
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
#   datagen = ImageDataGenerator(
#         rotation_range=40,
#         width_shift_range=0.2,
#         height_shift_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True,
#         vertical_flip=True,
#         brightness_range=(0.9,1.1),
#         fill_mode='nearest')

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# Image Path
original_image_path = '/content/drive/MyDrive/DISSERTATION/IMAGES_PREDICTION/akiec/ISIC_0024800.jpg'

# Load the image
img = load_img(original_image_path)
x = img_to_array(img)
x = x.reshape((1,) + x.shape)

# ImageDataGenerator values
datagen = ImageDataGenerator(rotation_range=40)

#Augmented images
augmented_images = datagen.flow(x, batch_size=1)
plt.figure(figsize=(10, 5))

#Original image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(array_to_img(x[0]))
plt.axis('off')
# Augmented image
plt.subplot(1, 2, 2)
plt.title('Augmented Image')
augmented_image = augmented_images.next()[0]
plt.imshow(array_to_img(augmented_image))
plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# Path to the original image
original_image_path = '/content/drive/MyDrive/DISSERTATION/IMAGES_PREDICTION/akiec/ISIC_0024800.jpg'

# Load the original image
img = load_img(original_image_path)
x = img_to_array(img)
x = x.reshape((1,) + x.shape)  # Reshape to (1, height, width, channels)

# Create an instance of the ImageDataGenerator with specified augmentation parameters
datagen = ImageDataGenerator(width_shift_range=0.2)

# Generate augmented images
augmented_images = datagen.flow(x, batch_size=1)

# Display the original and augmented images
plt.figure(figsize=(10, 5))

# Display original image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(array_to_img(x[0]))
plt.axis('off')

# Display augmented image
plt.subplot(1, 2, 2)
plt.title('Augmented Image')
augmented_image = augmented_images.next()[0]
plt.imshow(array_to_img(augmented_image))
plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# Path to the original image
original_image_path = '/content/drive/MyDrive/DISSERTATION/IMAGES_PREDICTION/akiec/ISIC_0024800.jpg'

# Load the original image
img = load_img(original_image_path)
x = img_to_array(img)
x = x.reshape((1,) + x.shape)  # Reshape to (1, height, width, channels)

# Create an instance of the ImageDataGenerator with specified augmentation parameters
datagen = ImageDataGenerator(height_shift_range=0.2)

# Generate augmented images
augmented_images = datagen.flow(x, batch_size=1)

# Display the original and augmented images
plt.figure(figsize=(10, 5))

# Display original image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(array_to_img(x[0]))
plt.axis('off')

# Display augmented image
plt.subplot(1, 2, 2)
plt.title('Augmented Image')
augmented_image = augmented_images.next()[0]
plt.imshow(array_to_img(augmented_image))
plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# Path to the original image
original_image_path = '/content/drive/MyDrive/DISSERTATION/IMAGES_PREDICTION/akiec/ISIC_0024800.jpg'

# Load the original image
img = load_img(original_image_path)
x = img_to_array(img)
x = x.reshape((1,) + x.shape)  # Reshape to (1, height, width, channels)

# Create an instance of the ImageDataGenerator with specified augmentation parameters
datagen = ImageDataGenerator(zoom_range=0.2)

# Generate augmented images
augmented_images = datagen.flow(x, batch_size=1)

# Display the original and augmented images
plt.figure(figsize=(10, 5))

# Display original image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(array_to_img(x[0]))
plt.axis('off')

# Display augmented image
plt.subplot(1, 2, 2)
plt.title('Augmented Image')
augmented_image = augmented_images.next()[0]
plt.imshow(array_to_img(augmented_image))
plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# Path to the original image
original_image_path = '/content/drive/MyDrive/DISSERTATION/IMAGES_PREDICTION/akiec/ISIC_0024800.jpg'

# Load the original image
img = load_img(original_image_path)
x = img_to_array(img)
x = x.reshape((1,) + x.shape)  # Reshape to (1, height, width, channels)

# Create an instance of the ImageDataGenerator with specified augmentation parameters
datagen = ImageDataGenerator( horizontal_flip=True)

# Generate augmented images
augmented_images = datagen.flow(x, batch_size=1)

# Display the original and augmented images
plt.figure(figsize=(10, 5))

# Display original image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(array_to_img(x[0]))
plt.axis('off')

# Display augmented image
plt.subplot(1, 2, 2)
plt.title('Augmented Image')
augmented_image = augmented_images.next()[0]
plt.imshow(array_to_img(augmented_image))
plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# Path to the original image
original_image_path = '/content/drive/MyDrive/DISSERTATION/IMAGES_PREDICTION/akiec/ISIC_0024800.jpg'

# Load the original image
img = load_img(original_image_path)
x = img_to_array(img)
x = x.reshape((1,) + x.shape)  # Reshape to (1, height, width, channels)

# Create an instance of the ImageDataGenerator with specified augmentation parameters
datagen = ImageDataGenerator( vertical_flip=True)

# Generate augmented images
augmented_images = datagen.flow(x, batch_size=1)

# Display the original and augmented images
plt.figure(figsize=(10, 5))

# Display original image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(array_to_img(x[0]))
plt.axis('off')

# Display augmented image
plt.subplot(1, 2, 2)
plt.title('Augmented Image')
augmented_image = augmented_images.next()[0]
plt.imshow(array_to_img(augmented_image))
plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# Path to the original image
original_image_path = '/content/drive/MyDrive/DISSERTATION/IMAGES_PREDICTION/akiec/ISIC_0024800.jpg'

# Load the original image
img = load_img(original_image_path)
x = img_to_array(img)
x = x.reshape((1,) + x.shape)  # Reshape to (1, height, width, channels)

# Create an instance of the ImageDataGenerator with specified augmentation parameters
datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=(0.9,1.1),
        fill_mode='nearest')

# Generate augmented images
augmented_images = datagen.flow(x, batch_size=1)

# Display the original and augmented images
plt.figure(figsize=(10, 5))

# Display original image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(array_to_img(x[0]))
plt.axis('off')

# Display augmented image
plt.subplot(1, 2, 2)
plt.title('Augmented Image')
augmented_image = augmented_images.next()[0]
plt.imshow(array_to_img(augmented_image))
plt.axis('off')

plt.show()
